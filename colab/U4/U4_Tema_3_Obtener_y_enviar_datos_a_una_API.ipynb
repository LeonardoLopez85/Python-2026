# %% [markdown]
# <a href="https://colab.research.google.com/github/crodriguezn/python-2025/blob/master/U4_Tema_3_Obtener_y_enviar_datos_a_una_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import string

def generar_password(longitud=12):
    caracteres = string.ascii_letters + string.digits + string.punctuation
    password = "".join(random.choice(caracteres) for _ in range(longitud))
    return password

print(generar_password(16))
# Out:
# HxuQ4-H~RKk0;2KK

# %%
import requests

# OBTENER DATOS
url = "https://jsonplaceholder.typicode.com/posts/1"
response = requests.get(url)
if response.status_code == 200:
    datos = response.json()
    print("Título del post:", datos["title"])
else:
    print("Error al obtener los datos")

# ENVIAR DATOS (POST)
nuevo_post = {
    "title": "Mi título",
    "body": "Contenido del post",
    "userId": 1
}

url_post = "https://jsonplaceholder.typicode.com/posts"
response_post = requests.post(url_post, json=nuevo_post)
if response_post.status_code == 201:
    print("Post creado:", response_post.json())
else:
    print("Error al crear el post")
# Out:
# Título del post: sunt aut facere repellat provident occaecati excepturi optio reprehenderit
# Post creado: {'title': 'Mi título', 'body': 'Contenido del post', 'userId': 1, 'id': 101}
